# %% [markdown]
# Задача 40: Определить среднюю стоимость дома, где кол-во людей от 0 до 500 (population).

# %%
import pandas as pd

# %%
df = pd.read_csv('sample_data/california_housing_train.csv')

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df[['population', 'median_house_value']]
# Out:
#        population  median_house_value
# 0          1015.0             66900.0
# 1          1129.0             80100.0
# 2           333.0             85700.0
# 3           515.0             73400.0
# 4           624.0             65500.0
# ...           ...                 ...
# 16995       907.0            111400.0
# 16996      1194.0             79000.0
# 16997      1244.0            103600.0
# 16998      1298.0             85800.0
# 16999       806.0             94600.0
#
# [17000 rows x 2 columns]

# %%
df_res = df[df['population'] < 500][['median_house_value', 'population']]

# %%
df_res
# Out:
#        median_house_value  population
# 2                 85700.0       333.0
# 7                 48500.0       375.0
# 17                25000.0        64.0
# 19                27500.0        29.0
# 21                59200.0       227.0
# ...                   ...         ...
# 16944            130600.0       320.0
# 16951             67500.0       235.0
# 16969             60000.0       392.0
# 16982            107000.0       480.0
# 16994             76100.0       434.0
#
# [1601 rows x 2 columns]

# %%
df_res['median_house_value'].mean()
# Out:
# 206683.83635227982

# %% [markdown]
# Станислав, здравствуйте!
# я как обыно бегу за поездом... Надеюсь успею сдать следующий семинар до 10 утра.
# Пока путаюсь в скобках и командах, но кажется 40ю задачу получилось сделать..?
# вопросов очень много, но думаю повторный просмотр этого семинара избавит меня от них)
# постараюсь подгрузить 42ю задачу о_о'
